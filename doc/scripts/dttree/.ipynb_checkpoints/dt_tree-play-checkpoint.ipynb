# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('play.csv')
df
# Out:
#    Weather  Temp Humidity Windy Play
# 0    Rainy   Hot     High    No   No
# 1    Rainy   Hot     High   Yes   No
# 2   Cloudy   Hot     High    No  Yes
# 3    Sunny  Mild     High    No  Yes
# 4    Sunny  Cool   Normal    No  Yes
# 5    Sunny  Cool   Normal   Yes   No
# 6   Cloudy  Cool   Normal   Yes  Yes
# 7    Rainy  Mild     High    No   No
# 8    Rainy  Cool   Normal    No  Yes
# 9    Sunny  Mild   Normal    No  Yes
# 10   Rainy  Mild   Normal   Yes  Yes
# 11  Cloudy  Mild     High   Yes  Yes
# 12  Cloudy   Hot   Normal    No  Yes
# 13   Sunny  Mild     High   Yes   No

# %%
c = list(df.columns)
c.remove('Play')
X = df[c]
y = df['Play']
X=pd.get_dummies(X)
X
# Out:
#     Weather_Cloudy  Weather_Rainy  Weather_Sunny  Temp_Cool  Temp_Hot  \
# 0                0              1              0          0         1
# 1                0              1              0          0         1
# 2                1              0              0          0         1
# 3                0              0              1          0         0
# 4                0              0              1          1         0
# 5                0              0              1          1         0
# 6                1              0              0          1         0
# 7                0              1              0          0         0
# 8                0              1              0          1         0
# 9                0              0              1          0         0
# 10               0              1              0          0         0
# 11               1              0              0          0         0
# 12               1              0              0          0         1
# 13               0              0              1          0         0
#
#     Temp_Mild  Humidity_High  Humidity_Normal  Windy_No  Windy_Yes
# 0           0              1                0         1          0
# 1           0              1                0         0          1
# 2           0              1                0         1          0
# 3           1              1                0         1          0
# 4           0              0                1         1          0
# 5           0              0                1         0          1
# 6           0              0                1         0          1
# 7           1              1                0         1          0
# 8           0              0                1         1          0
# 9           1              0                1         1          0
# 10          1              0                1         0          1
# 11          1              1                0         0          1
# 12          0              0                1         1          0
# 13          1              1                0         0          1

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(X, y)

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dt_try")
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-6-df6d6fd22b31> in <module>()
#       2 dot_data = tree.export_graphviz(clf, out_file=None)
#       3 graph = graphviz.Source(dot_data)
# ----> 4 graph.render("dt_try")
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/graphviz/files.pyc in render(self, filename, directory, view, cleanup)
#     173         filepath = self.save(filename, directory)
#     174
# --> 175         rendered = backend.render(self._engine, self._format, filepath)
#     176
#     177         if cleanup:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/graphviz/backend.pyc in render(engine, format, filepath, quiet)
#     122     with open(os.devnull, 'w') as stderr:
#     123         try:
# --> 124             subprocess.check_call(args, startupinfo=STARTUPINFO, stderr=stderr)
#     125         except OSError as e:
#     126             if e.errno == errno.ENOENT:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in check_call(*popenargs, **kwargs)
#     184         if cmd is None:
#     185             cmd = popenargs[0]
# --> 186         raise CalledProcessError(retcode, cmd)
#     187     return 0
#     188
#
# CalledProcessError: Command '['dot', '-Tpdf', '-O', 'dt_try']' returned non-zero exit status 1

# %%
target = ['No','Yes']
dot_data = tree.export_graphviz(clf, out_file=None,                          
                                feature_names=X.columns,  
                                class_names= target ,  
                                filled=True, rounded=True,  
                                special_characters=True) 
graph = graphviz.Source(dot_data)  
graph

# %%
df
# Out:
#    Weather  Temp Humidity Windy Play
# 0    Rainy   Hot     High    No   No
# 1    Rainy   Hot     High   Yes   No
# 2   Cloudy   Hot     High    No  Yes
# 3    Sunny  Mild     High    No  Yes
# 4    Sunny  Cool   Normal    No  Yes
# 5    Sunny  Cool   Normal   Yes   No
# 6   Cloudy  Cool   Normal   Yes  Yes
# 7    Rainy  Mild     High    No   No
# 8    Rainy  Cool   Normal    No  Yes
# 9    Sunny  Mild   Normal    No  Yes
# 10   Rainy  Mild   Normal   Yes  Yes
# 11  Cloudy  Mild     High   Yes  Yes
# 12  Cloudy   Hot   Normal    No  Yes
# 13   Sunny  Mild     High   Yes   No

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("dt_try") 
target = ['No','Yes']
dot_data = tree.export_graphviz(clf, out_file=None,                          
                                feature_names=X.columns,  
                                class_names= target ,  
                                filled=True, rounded=True,  
                                special_characters=True) 
graph = graphviz.Source(dot_data)  
graph

# %%
1-(4/6)^2-(6/10)^2
# Out:
# 1
